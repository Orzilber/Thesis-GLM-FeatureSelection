# %%
import pickle
with open('sim_dict_0', 'rb') as f:
    results = pickle.load(f)

# %%
results.keys()
# Out:
# dict_keys([(20, 1, 0), (20, 2, 0), (20, 3, 0), (20, 4, 0), (20, 5, 0), (20, 6, 0), (20, 7, 0), (20, 10, 0), (20, 14, 0), (20, 18, 0), (100, 5, 0), (100, 10, 0), (100, 15, 0), (100, 20, 0), (100, 25, 0), (100, 30, 0), (100, 35, 0), (100, 50, 0), (100, 70, 0), (100, 90, 0)])

# %%
results[(100, 90, 0)]
# Out:
# [{'FWD': {'nll': 99.47784200169022,
#    'KL': 789.7730438927248,
#    'KL_theta_train': 202.2612654239046,
#    'KL_theta_test': 101.09028567525652,
#    'size': 2},
#   'LASSO': {'nll': 100.0,
#    'KL': 793.400370805314,
#    'KL_theta_train': 200.39642266128874,
#    'KL_theta_test': 100.02458503134756,
#    'size': 0},
#   'SLOPE': {'nll': 100.0,
#    'KL': 793.400370805314,
#    'KL_theta_train': 200.39642266128874,
#    'KL_theta_test': 100.02458503134756,
#    'size': 0}},
#  {'FWD': {'nll': 105.11780025127327,
#    'KL': 994.3068818078486,
#    'KL_theta_train': 213.01096862464078,
#    'KL_theta_test': 96.03009586868365,
#    'size': 2},
#   'LASSO': {'nll': 100.0,
#    'KL': 1024.5188265221016,
#    'KL_theta_train': 199.72546198002505,
#    'KL_theta_test': 100.31138714549701,
#    'size': 0},
#   'SLOPE': {'nll': 100.0,
#    'KL': 1024.5188265221016,
#    'KL_theta_train': 199.72546198002505,
#    'KL_theta_test': 100.31138714549701,
#    'size': 0}},
# ...
